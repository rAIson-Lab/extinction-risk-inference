# %%
import sys, os, random
sys.path.append(os.path.join(os.getcwd(), 'CONFOLD')) #add CONFOLD to path

import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

import pandas as pd

from foldrm import Classifier
from datasets import  final_extinctionrisk_dataframe, final_extinctionrisk_noth_dataframe

from algo import prune_rules

# %%
random.seed(42)

# %% [markdown]
# # Without Human Threats

# %%
model_template, data = final_extinctionrisk_noth_dataframe()
X = data[model_template.attrs].drop('Extinction_risk',axis=1)
X = X.convert_dtypes()
X = X.to_numpy()
y = data['Extinction_risk'].to_numpy()

# %% [markdown]
# # Loading the Train/Test Splits from R

# %%
import csv

train_indices = []
test_indices = []
for i in range(1,11):
    with open("./datasets/r_folds/fold_"+str(i)+"_train_idx.csv", newline='') as csvfile:
        train_df = pd.read_csv(csvfile)
        train_list = train_df.to_numpy().flatten().tolist()
        train_indices.append(train_list)
    with open("./datasets/r_folds/fold_"+str(i)+"_test_idx.csv", newline='') as csvfile:
        test_df = pd.read_csv(csvfile)
        test_list = test_df.to_numpy().flatten().tolist()
        test_indices.append(test_list)

# %% [markdown]
# # K-Fold Cross Validation Without Human Threats.
# - Data Driven Model

# %%
acc_metrics = []
f1_metrics = [] 
precision_metrics = []
recall_metrics = []


for i, (train_index, test_index) in enumerate(zip(train_indices, test_indices)):
    print("Fold "+str(i)+":")
    
    train_data = np.concatenate((np.array(X[train_index]), np.array(y[train_index]).reshape(-1, 1)), axis=1).tolist()
    test_data = np.concatenate((np.array(X[test_index]), np.array(y[test_index]).reshape(-1, 1)), axis=1).tolist()
 
    # Prepare the test data (features and true labels)
    X_test = [d[:-1] for d in test_data]
    Y_test = [d[-1] for d in test_data]

    advanced_pruning_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)

    # Now, train using confidence_fit with a high 15% improvement threshold
    advanced_pruning_model.confidence_fit(train_data, improvement_threshold=0.20)
    advanced_pruning_model.print_asp(simple=True)


    adv_pruning_predictions = advanced_pruning_model.predict(X_test)
    adv_pruning_labels = [p[0] for p in adv_pruning_predictions]

    for i in range(len(adv_pruning_labels)):
        if adv_pruning_labels[i] is None:
            adv_pruning_labels[i] = ('None')
    acc = accuracy_score(Y_test, adv_pruning_labels)

    f1 = f1_score(Y_test, adv_pruning_labels, average=None, labels=["Higher_risk", "Lower_risk"]) #["Higher_risk", "Lower_risk"]["Lower_risk", "Higher_risk"]
    precision = precision_score(Y_test,adv_pruning_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    recall = recall_score(Y_test, adv_pruning_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    
    acc_metrics.append(acc)    
    f1_metrics.append(f1)
    precision_metrics.append(precision)
    recall_metrics.append(recall)

    print("----------------------------------------")
    print()
# Out:
# Fold 0:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15797.46. [confidence: 0.87839]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.75422]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=12.1, minimum_latitude(X,N8), N8>-21.91, island_restricted_breeding(X,N11), N11>0. [confidence: 0.69669]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>3.6433. [confidence: 0.77542]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N8), N8<=9.98, maximum_latitude(X,N9), N9>-0.17. [confidence: 0.77326]
# extinction_risk(X,'higher_risk') :- wing_length(X,N5), N5>46.7. [confidence: 0.70763]
# extinction_risk(X,'lower_risk') :- not order(X,'caprimulgiformes'). [confidence: 0.65385]
# extinction_risk(X,'lower_risk') :- order(X,'caprimulgiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 1:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.87671]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3161.83. [confidence: 0.75608]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0, body_mass(X,N22), N22<=56.0. [confidence: 0.74202]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N4), N4<=66.5, minimum_elevation(X,N17), N17<=1350, maximum_elevation(X,N18), N18<=2750.0, adult_survival_annual(X,N19), N19>0.69525. [confidence: 0.65625]
# extinction_risk(X,'lower_risk') :- maximum_elevation(X,N18), N18>2750.0, adult_survival_annual(X,N19), N19<=0.79276. [confidence: 0.71023]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N19), N19>0.69525. [confidence: 0.8625]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N3), N3<=5.6, tail_length(X,N7), N7>76.2. [confidence: 0.78571]
# extinction_risk(X,'lower_risk') :- wing_length(X,N5), N5>74.8. [confidence: 0.67424]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8<=-14.18. [confidence: 0.775]
# extinction_risk(X,'higher_risk') :- diet(X,'granivore'). [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N8), N8<=-9.9. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=4525.06. [confidence: 0.75]
# extinction_risk(X,'lower_risk') :- habitat_breadth(X,N14), N14>1. [confidence: 0.65278]
# extinction_risk(X,'higher_risk') :- hand_wing_index(X,N6), N6>10.2. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 2:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.87904]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.7533]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=12.1, minimum_latitude(X,N8), N8>-21.91, island_restricted_breeding(X,N11), N11>0. [confidence: 0.70513]
# extinction_risk(X,'higher_risk') :- maximum_elevation(X,N18), N18<=2550.0. [confidence: 0.66598]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=20.6. [confidence: 0.77692]
# extinction_risk(X,'higher_risk') :- wing_length(X,N5), N5>91.3. [confidence: 0.775]
# extinction_risk(X,'higher_risk') :- tail_length(X,N7), N7<=49.5. [confidence: 0.60714]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 3:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.87915]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.76083]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0, body_mass(X,N22), N22<=74.2. [confidence: 0.72877]
# extinction_risk(X,'higher_risk') :- not order(X,'gruiformes'), beak_length_culmen(X,N2), N2>9.1, tarsus_length(X,N4), N4<=66.5, elevational_range(X,N13), N13<=1000, clutch_size(X,N23), N23>1.0. [confidence: 0.66754]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=17.9, beak_depth(X,N3), N3<=12.8. [confidence: 0.79286]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N4), N4>65.5. [confidence: 0.82]
# extinction_risk(X,'higher_risk') :- realm(X,'i'), elevational_range(X,N13), N13>1050. [confidence: 0.74]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2>35.4, beak_depth(X,N3), N3<=12.3. [confidence: 0.79545]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8>12.3. [confidence: 0.76087]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=31.2. [confidence: 0.64754]
# extinction_risk(X,'higher_risk') :- maximum_elevation(X,N18), N18>1100.0. [confidence: 0.775]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# extinction_risk(X,'lower_risk') :- order(X,'suliformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 4:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.88008]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.75608]
# extinction_risk(X,'lower_risk') :- generation_length(X,N20), N20<=5.2865, body_mass(X,N22), N22<=17.0. [confidence: 0.71106]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>5.2865. [confidence: 0.78571]
# extinction_risk(X,'lower_risk') :- family(X,'meliphagidae'). [confidence: 0.76087]
# extinction_risk(X,'lower_risk') :- maximum_elevation(X,N18), N18>2900.0. [confidence: 0.69444]
# extinction_risk(X,'higher_risk') :- island_restricted_breeding(X,N11), N11<=0. [confidence: 0.665]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N13), N13>100, habitat_breadth(X,N14), N14>1, maximum_elevation(X,N18), N18<=2000.0. [confidence: 0.69802]
# extinction_risk(X,'higher_risk') :- body_mass(X,N22), N22<=32.1. [confidence: 0.79545]
# extinction_risk(X,'higher_risk') :- wing_length(X,N5), N5>97.4. [confidence: 0.68367]
# extinction_risk(X,'lower_risk') :- tail_length(X,N7), N7<=80.2. [confidence: 0.73529]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'psittaciformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 5:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.87778]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.75729]
# extinction_risk(X,'lower_risk') :- body_mass(X,N22), N22<=17.0. [confidence: 0.71535]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N3), N3>12.3. [confidence: 0.72283]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N6), N6>6.1, tail_length(X,N7), N7>72.9, maximum_latitude(X,N9), N9>-3.62, maximum_elevation(X,N18), N18>100.0, adult_survival_annual(X,N19), N19>0.54866. [confidence: 0.68803]
# extinction_risk(X,'higher_risk') :- not order(X,'psittaciformes'), hand_wing_index(X,N6), N6>10.8, tail_length(X,N7), N7>63.4, maximum_elevation(X,N18), N18<=2750.0, adult_survival_annual(X,N19), N19<=0.80708, generation_length(X,N20), N20<=5.30538. [confidence: 0.6875]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>5.19799. [confidence: 0.78571]
# extinction_risk(X,'lower_risk') :- tail_length(X,N7), N7>50.2, minimum_latitude(X,N8), N8<=9.94, maximum_elevation(X,N18), N18>250.0. [confidence: 0.72034]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=925. [confidence: 0.7766]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=20.5, body_mass(X,N22), N22>19.9. [confidence: 0.71154]
# extinction_risk(X,'higher_risk') :- not family(X,'sturnidae'). [confidence: 0.76316]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 6:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.87749]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.74581]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=12.1, minimum_latitude(X,N8), N8>-21.91, island_restricted_breeding(X,N11), N11>0. [confidence: 0.69273]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N19), N19>0.76741. [confidence: 0.82317]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N2), N2>9.1, elevational_range(X,N13), N13<=1000. [confidence: 0.67105]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=18.9. [confidence: 0.7716]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=5928.3. [confidence: 0.76316]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N9), N9<=8.91. [confidence: 0.70455]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=11.3. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>3.59778. [confidence: 0.65385]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=19.3. [confidence: 0.625]
# extinction_risk(X,'higher_risk') :- order(X,'psittaciformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 7:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.87715]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.75171]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=12.1, island_restricted_breeding(X,N11), N11>0. [confidence: 0.67314]
# extinction_risk(X,'higher_risk') :- wing_length(X,N5), N5>130.8. [confidence: 0.79444]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N13), N13>1000. [confidence: 0.68981]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=5149.75. [confidence: 0.81429]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13>765. [confidence: 0.78205]
# extinction_risk(X,'lower_risk') :- adult_survival_annual(X,N19), N19<=0.53279. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N2), N2<=30.0, body_mass(X,N22), N22>62.0. [confidence: 0.71053]
# extinction_risk(X,'lower_risk') :- body_mass(X,N22), N22>42.0. [confidence: 0.775]
# extinction_risk(X,'higher_risk') :- tail_length(X,N7), N7>48.2. [confidence: 0.69048]
# extinction_risk(X,'lower_risk') :- tail_length(X,N7), N7>32.9. [confidence: 0.69444]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 8:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.87818]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.75546]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N13), N13>1000, body_mass(X,N22), N22<=97.9. [confidence: 0.72613]
# extinction_risk(X,'higher_risk') :- island_restricted_breeding(X,N11), N11<=0. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- adult_survival_annual(X,N19), N19<=0.82595, body_mass(X,N22), N22<=16.6. [confidence: 0.79464]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N19), N19>0.82595. [confidence: 0.82692]
# extinction_risk(X,'lower_risk') :- not family(X,'turdidae'), beak_depth(X,N3), N3<=13.2, elevational_range(X,N13), N13>100, body_mass(X,N22), N22>21.5, body_mass(X,N22), N22<=114.0. [confidence: 0.73718]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20<=3.1717. [confidence: 0.82692]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N4), N4<=18.0. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8>17.7. [confidence: 0.69444]
# extinction_risk(X,'lower_risk') :- tail_length(X,N7), N7<=84.0. [confidence: 0.725]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N4), N4>43.5. [confidence: 0.68519]
# extinction_risk(X,'lower_risk') :- adult_survival_annual(X,N19), N19>0.81096. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- tail_length(X,N7), N7<=149.8. [confidence: 0.625]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=39.9. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- not order(X,'cuculiformes'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'cuculiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 9:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.87717]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3523.43. [confidence: 0.74059]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0, body_mass(X,N22), N22<=86.0. [confidence: 0.7488]
# extinction_risk(X,'higher_risk') :- not habitat(X,'shrub'), tarsus_length(X,N4), N4<=66.5, wing_length(X,N5), N5>46.8, habitat_breadth(X,N14), N14<=1, maximum_elevation(X,N18), N18<=2750.0, range_size(X,N21), N21>3653.25, clutch_size(X,N23), N23>1.45. [confidence: 0.77439]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N4), N4>66.5. [confidence: 0.79545]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N8), N8>7.8, minimum_latitude(X,N8), N8<=14.53. [confidence: 0.7378]
# extinction_risk(X,'higher_risk') :- tail_length(X,N7), N7>79.5, clutch_size(X,N23), N23>1.45. [confidence: 0.75]
# extinction_risk(X,'lower_risk') :- clutch_size(X,N23), N23<=1.86364. [confidence: 0.71212]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N2), N2>9.6, range_size(X,N21), N21<=11101.97. [confidence: 0.65323]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=7.1. [confidence: 0.76562]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'psittaciformes'). [confidence: 0.59091]
# ----------------------------------------

# %%
print("Data Driven Model")
print(f"KFold Mean Acc: {round(np.mean(acc_metrics), 5)} | KFold SD: {np.std(acc_metrics)}")
f1_metrics = np.array(f1_metrics)
precision_metrics = np.array(precision_metrics)
recall_metrics = np.array(recall_metrics)

print(f"KFold Mean Precision: Higher Risk {round(np.mean(precision_metrics[:,0]), 5)}, Lower Risk {round(np.mean(precision_metrics[:,1]), 5)}  | KFold SD: {round(np.std(precision_metrics[:, 0]),5), round(np.std(precision_metrics[:, 1]), 5)}")
print(f"KFold Mean Recall: Higher Risk {round(np.mean(recall_metrics[:,0]), 5)}, Lower Risk {round(np.mean(recall_metrics[:,1]), 5)} | KFold SD: {round(np.std(recall_metrics[:, 0]), 5), round(np.std(recall_metrics[:, 1]), 5)}")
print(f"KFold Mean f1: Higher Risk {round(np.mean(f1_metrics[:,0]), 5)}, Lower Risk {round(np.mean(f1_metrics[:,1]), 5)} | KFold SD: {round(np.std(f1_metrics[:,0]), 5), round(np.std(f1_metrics[:,1]), 5)}")
# Out:
# Data Driven Model
# KFold Mean Acc: 0.8511 | KFold SD: 0.009967351334719089
# KFold Mean Precision: Higher Risk 0.7081, Lower Risk 0.86682  | KFold SD: (np.float64(0.0433), np.float64(0.00803))
# KFold Mean Recall: Higher Risk 0.36825, Lower Risk 0.96453 | KFold SD: (np.float64(0.04266), np.float64(0.00518))
# KFold Mean f1: Higher Risk 0.48375, Lower Risk 0.91305 | KFold SD: (np.float64(0.04501), np.float64(0.00555))

# %% [markdown]
# # K-Fold Cross Validation Without Human Threats.
# - Expert Rule Model

# %%
acc_metrics = []
f1_metrics = [] 
precision_metrics = []
recall_metrics = []


for i, (train_index, test_index) in enumerate(zip(train_indices, test_indices)):
    print("Fold "+str(i)+":")
    
    train_data = np.concatenate((np.array(X[train_index]), np.array(y[train_index]).reshape(-1, 1)), axis=1).tolist()
    test_data = np.concatenate((np.array(X[test_index]), np.array(y[test_index]).reshape(-1, 1)), axis=1).tolist()
 
    # Prepare the test data (features and true labels)
    X_test = [d[:-1] for d in test_data]
    Y_test = [d[-1] for d in test_data]

    # Instantiate a new classifier for expert-guided model
    expert_model = Classifier(attrs=model_template.attrs.copy(), numeric=model_template.numeric, label=model_template.label)

    # Define our expert rules as strings
    rule1 = "with confidence 0.99 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Body_mass' '>=' '130' and 'Generation_length' '>=' '4.068' and 'Elevational_range' '<=' '800'"
    rule2 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Body_mass' '>=' '130' and 'Elevational_range' '<=' '800'"
    rule3 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Generation_length' '>=' '4.068' and 'Elevational_range' '<=' '800'"
    rule4 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Body_mass' '>=' '130' and 'Generation_length' '>=' '4.068'"
    rule5 = "with confidence 0.95 class = 'Higher_risk' if 'Body_mass' '>=' '130' and 'Generation_length' '>=' '4.068' and 'Elevational_range' '<=' '800'"

    # Add the manual rules to the model
    expert_model.add_manual_rule(rule1, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule2, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule3, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule4, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule5, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)

    #expert_model.fit(train_data, ratio=0.75)

    expert_model.confidence_fit(train_data, improvement_threshold=0.20)
    expert_model.print_asp(simple=True)


    expert_predictions_tuples = expert_model.predict(X_test)
    expert_predicted_labels = [p[0] for p in expert_predictions_tuples]

    acc = accuracy_score(Y_test, expert_predicted_labels)

    f1 = f1_score(Y_test, expert_predicted_labels, average=None, labels=["Higher_risk", "Lower_risk"]) #["Higher_risk", "Lower_risk"]["Lower_risk", "Higher_risk"]
    precision = precision_score(Y_test,expert_predicted_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    recall = recall_score(Y_test, expert_predicted_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    
    acc_metrics.append(acc)    
    f1_metrics.append(f1)
    precision_metrics.append(precision)
    recall_metrics.append(recall)

    print("----------------------------------------")
    print()
# Out:
# Fold 0:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>14884.37. [confidence: 0.90306]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72162]
# extinction_risk(X,'lower_risk') :- not family(X,'meliphagidae'), tail_length(X,N7), N7<=53.6, minimum_latitude(X,N8), N8>-21.91. [confidence: 0.71296]
# extinction_risk(X,'lower_risk') :- family(X,'meliphagidae'). [confidence: 0.81944]
# extinction_risk(X,'higher_risk') :- not family(X,'pachycephalidae'), maximum_latitude(X,N9), N9<=8.91. [confidence: 0.66288]
# extinction_risk(X,'lower_risk') :- generation_length(X,N20), N20>2.75206. [confidence: 0.71023]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N2), N2<=12.9, maximum_elevation(X,N18), N18<=3000.0. [confidence: 0.67857]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=14.8. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- not order(X,'strigiformes'), not family(X,'tyrannidae'). [confidence: 0.63514]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'strigiformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 1:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.90051]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3251.0. [confidence: 0.7241]
# extinction_risk(X,'lower_risk') :- not family(X,'meliphagidae'), tail_length(X,N7), N7<=53.6, minimum_latitude(X,N8), N8>-21.91. [confidence: 0.70118]
# extinction_risk(X,'lower_risk') :- family(X,'meliphagidae'). [confidence: 0.82812]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N9), N9>9.48, maximum_latitude(X,N9), N9<=18.53. [confidence: 0.72396]
# extinction_risk(X,'higher_risk') :- not realm(X,'o'), not realm(X,'f'), not family(X,'pachycephalidae'), not family(X,'rhipiduridae'), beak_length_culmen(X,N2), N2<=26.6, tail_length(X,N7), N7>56.3, maximum_elevation(X,N18), N18<=2750.0. [confidence: 0.66111]
# extinction_risk(X,'higher_risk') :- tail_length(X,N7), N7<=53.8. [confidence: 0.76316]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=20.6. [confidence: 0.65686]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N19), N19>0.70841. [confidence: 0.80435]
# extinction_risk(X,'higher_risk') :- body_mass(X,N22), N22<=50.0. [confidence: 0.67647]
# extinction_risk(X,'lower_risk') :- not family(X,'sturnidae'). [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 2:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.90262]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.69094]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8<=-13.51, maximum_elevation(X,N18), N18<=2470.0. [confidence: 0.80303]
# extinction_risk(X,'lower_risk') :- maximum_elevation(X,N18), N18>2470.0. [confidence: 0.70625]
# extinction_risk(X,'higher_risk') :- maximum_elevation(X,N18), N18>2350.0. [confidence: 0.73529]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N19), N19>0.73692. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=11.3, minimum_latitude(X,N8), N8<=9.83, maximum_latitude(X,N9), N9>9.95. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8>-9.9, habitat_breadth(X,N14), N14<=4. [confidence: 0.64493]
# extinction_risk(X,'lower_risk') :- not family(X,'thamnophilidae'). [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 3:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16794.51. [confidence: 0.90343]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72462]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.70117]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=1000. [confidence: 0.65909]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=18.9. [confidence: 0.76667]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=6382.86. [confidence: 0.775]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N9), N9>9.76. [confidence: 0.69048]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>3.26069. [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2>20.9. [confidence: 0.625]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 4:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.90388]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72833]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.69336]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N13), N13>1000. [confidence: 0.6681]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N2), N2>9.1. [confidence: 0.70098]
# extinction_risk(X,'lower_risk') :- order(X,'caprimulgiformes'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 5:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>20065.88. [confidence: 0.90398]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72511]
# extinction_risk(X,'lower_risk') :- body_mass(X,N22), N22<=17.0. [confidence: 0.72553]
# extinction_risk(X,'lower_risk') :- primary_lifestyle(X,'insessorial'), beak_depth(X,N3), N3<=12.8, wing_length(X,N5), N5>82.2. [confidence: 0.68367]
# extinction_risk(X,'higher_risk') :- maximum_elevation(X,N18), N18<=2480.0. [confidence: 0.68519]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N6), N6<=8.6. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- maximum_elevation(X,N18), N18<=3500.0. [confidence: 0.62821]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.65385]
# ----------------------------------------
#
# Fold 6:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>13210.57. [confidence: 0.89935]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.71569]
# extinction_risk(X,'lower_risk') :- not family(X,'meliphagidae'), minimum_latitude(X,N8), N8>-21.91, body_mass(X,N22), N22<=17.0. [confidence: 0.70126]
# extinction_risk(X,'lower_risk') :- family(X,'meliphagidae'). [confidence: 0.81944]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N9), N9<=-11.86. [confidence: 0.77632]
# extinction_risk(X,'lower_risk') :- not realm(X,'i'), not order(X,'columbiformes'), habitat_breadth(X,N14), N14>1, range_size(X,N21), N21<=12401.49, body_mass(X,N22), N22>20.7. [confidence: 0.70098]
# extinction_risk(X,'higher_risk') :- wing_length(X,N5), N5<=77.2, hand_wing_index(X,N6), N6<=27.9, minimum_latitude(X,N8), N8<=10.51. [confidence: 0.74]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8>10.51. [confidence: 0.83333]
# extinction_risk(X,'higher_risk') :- hand_wing_index(X,N6), N6>27.9. [confidence: 0.76316]
# extinction_risk(X,'lower_risk') :- diet(X,'invertebrate'), maximum_latitude(X,N9), N9>-3.05. [confidence: 0.72222]
# extinction_risk(X,'higher_risk') :- body_mass(X,N22), N22>70.9. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- clutch_size(X,N23), N23<=3.0. [confidence: 0.60417]
# extinction_risk(X,'lower_risk') :- not order(X,'caprimulgiformes'). [confidence: 0.625]
# extinction_risk(X,'lower_risk') :- order(X,'caprimulgiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 7:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>13210.57. [confidence: 0.89916]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72272]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.67621]
# extinction_risk(X,'higher_risk') :- not habitat(X,'shrub'), beak_depth(X,N3), N3>10.7, minimum_latitude(X,N8), N8>-13.51, maximum_elevation(X,N18), N18<=2900.0. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=1000. [confidence: 0.68947]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N8), N8<=10.48. [confidence: 0.70833]
# extinction_risk(X,'higher_risk') :- not family(X,'paridae'). [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 8:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>13210.57. [confidence: 0.90045]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72309]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.68341]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=1000. [confidence: 0.67553]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=20.1. [confidence: 0.74658]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=6446.42. [confidence: 0.775]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=5.5. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- diet_breadth(X,N15), N15>1. [confidence: 0.65385]
# extinction_risk(X,'lower_risk') :- not order(X,'passeriformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N4), N4<=44.3. [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 9:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16947.76. [confidence: 0.9009]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3523.43. [confidence: 0.71146]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.71687]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=1000. [confidence: 0.66522]
# extinction_risk(X,'lower_risk') :- tail_length(X,N7), N7<=109.2. [confidence: 0.69266]
# extinction_risk(X,'higher_risk') :- not order(X,'columbiformes'). [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- order(X,'columbiformes'). [confidence: 0.55]
# ----------------------------------------

# %%
print("Expert Rule Model")
print(f"KFold Mean Acc: {round(np.mean(acc_metrics), 5)} | KFold SD: {np.std(acc_metrics)}")
f1_metrics = np.array(f1_metrics)
precision_metrics = np.array(precision_metrics)
recall_metrics = np.array(recall_metrics)

print(f"KFold Mean Precision: Higher Risk {round(np.mean(precision_metrics[:,0]), 5)}, Lower Risk {round(np.mean(precision_metrics[:,1]), 5)}  | KFold SD: {round(np.std(precision_metrics[:, 0]),5), round(np.std(precision_metrics[:, 1]), 5)}")
print(f"KFold Mean Recall: Higher Risk {round(np.mean(recall_metrics[:,0]), 5)}, Lower Risk {round(np.mean(recall_metrics[:,1]), 5)} | KFold SD: {round(np.std(recall_metrics[:, 0]), 5), round(np.std(recall_metrics[:, 1]), 5)}")
print(f"KFold Mean f1: Higher Risk {round(np.mean(f1_metrics[:,0]), 5)}, Lower Risk {round(np.mean(f1_metrics[:,1]), 5)} | KFold SD: {round(np.std(f1_metrics[:,0]), 5), round(np.std(f1_metrics[:,1]), 5)}")
# Out:
# Expert Rule Model
# KFold Mean Acc: 0.83011 | KFold SD: 0.01445848427818524
# KFold Mean Precision: Higher Risk 0.55808, Lower Risk 0.88908  | KFold SD: (np.float64(0.04093), np.float64(0.01119))
# KFold Mean Recall: Higher Risk 0.51982, Lower Risk 0.90301 | KFold SD: (np.float64(0.0534), np.float64(0.01348))
# KFold Mean f1: Higher Risk 0.53723, Lower Risk 0.89591 | KFold SD: (np.float64(0.04186), np.float64(0.00901))

# %% [markdown]
# # Training on Complete Dataset
# - without Expert Rules
# - and without Human Threats

# %%
baseline_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)
train_data = np.concatenate((np.array(X), np.array(y).reshape(-1, 1)), axis=1).tolist()

advanced_pruning_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)
advanced_pruning_model.confidence_fit(train_data, improvement_threshold=0.20)
advanced_pruning_model.print_asp(simple=True)
# Out:
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>15801.31. [confidence: 0.8779]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.75379]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=12.1, minimum_latitude(X,N8), N8>-21.91, island_restricted_breeding(X,N11), N11>0. [confidence: 0.69732]
# extinction_risk(X,'higher_risk') :- maximum_elevation(X,N18), N18<=2750.0. [confidence: 0.67375]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=18.8. [confidence: 0.78814]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N8), N8>8.76. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- tail_length(X,N7), N7>95.3. [confidence: 0.65385]
# extinction_risk(X,'higher_risk') :- wing_length(X,N5), N5>91.3. [confidence: 0.67857]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>7907.78. [confidence: 0.61765]
# extinction_risk(X,'higher_risk') :- order(X,'caprimulgiformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]

# %% [markdown]
# # Training on Complete Dataset
# - With Expert Rules
# - and without Human Threats

# %%
train_data = np.concatenate((np.array(X), np.array(y).reshape(-1, 1)), axis=1).tolist()

expert_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)

# Define our expert rules as strings
rule1 = "with confidence 0.99 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Body_mass' '>=' '130' and 'Generation_length' '>=' '4.068' and 'Elevational_range' '<=' '800'"
rule2 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Body_mass' '>=' '130' and 'Elevational_range' '<=' '800'"
rule3 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Generation_length' '>=' '4.068' and 'Elevational_range' '<=' '800'"
rule4 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Body_mass' '>=' '130' and 'Generation_length' '>=' '4.068'"
rule5 = "with confidence 0.95 class = 'Higher_risk' if 'Body_mass' '>=' '130' and 'Generation_length' '>=' '4.068' and 'Elevational_range' '<=' '800'"

# Add the manual rules to the model
expert_model.add_manual_rule(rule1, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule2, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule3, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule4, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule5, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)

#expert_model.fit(train_data, ratio=0.75)

expert_model.confidence_fit(train_data, improvement_threshold=0.20)
expert_model.print_asp(simple=True)
# Out:
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- generation_length(X,N20), N20>4.068, range_size(X,N21), N21<=75321, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=800, generation_length(X,N20), N20>4.068, body_mass(X,N22), N22>130. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- range_size(X,N21), N21>16469.54. [confidence: 0.90208]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=3270.79. [confidence: 0.72233]
# extinction_risk(X,'lower_risk') :- island_restricted_breeding(X,N11), N11>0. [confidence: 0.69326]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N13), N13<=1000. [confidence: 0.66529]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N2), N2<=18.9. [confidence: 0.76437]
# extinction_risk(X,'higher_risk') :- range_size(X,N21), N21<=6446.42. [confidence: 0.78571]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N9), N9>9.76. [confidence: 0.70455]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N2), N2<=22.7. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N3), N3<=8.4. [confidence: 0.625]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# extinction_risk(X,'higher_risk') :- order(X,'trogoniformes'). [confidence: 0.55]
