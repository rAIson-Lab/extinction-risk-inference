# %%
import sys, os, random
sys.path.append(os.path.join(os.getcwd(), 'CONFOLD')) #add CONFOLD to path

import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

import pandas as pd

from foldrm import Classifier
from datasets import  final_extinctionrisk_dataframe, final_extinctionrisk_noth_dataframe

from algo import prune_rules

# %%
random.seed(42)

# %% [markdown]
# # With Human Threats

# %%
model_template, data = final_extinctionrisk_dataframe()
X = data[model_template.attrs].drop('Extinction_risk',axis=1)
X = X.convert_dtypes()
X = X.to_numpy()
y = data['Extinction_risk'].to_numpy()

# %% [markdown]
# # Loading the Train/Test Splits from R

# %%
import csv

train_indices = []
test_indices = []
for i in range(1,11):
    with open("./datasets/r_folds/fold_"+str(i)+"_train_idx.csv", newline='') as csvfile:
        train_df = pd.read_csv(csvfile)
        train_list = train_df.to_numpy().flatten().tolist()
        train_indices.append(train_list)
    with open("./datasets/r_folds/fold_"+str(i)+"_test_idx.csv", newline='') as csvfile:
        test_df = pd.read_csv(csvfile)
        test_list = test_df.to_numpy().flatten().tolist()
        test_indices.append(test_list)

# %% [markdown]
# # K-Fold Cross Validation With Human Threats.
# - Data Driven Model

# %%
acc_metrics = []
f1_metrics = [] 
precision_metrics = []
recall_metrics = []


for i, (train_index, test_index) in enumerate(zip(train_indices, test_indices)):
    print("Fold "+str(i)+":")
    
    train_data = np.concatenate((np.array(X[train_index]), np.array(y[train_index]).reshape(-1, 1)), axis=1).tolist()
    test_data = np.concatenate((np.array(X[test_index]), np.array(y[test_index]).reshape(-1, 1)), axis=1).tolist()
 
    # Prepare the test data (features and true labels)
    X_test = [d[:-1] for d in test_data]
    Y_test = [d[-1] for d in test_data]

    advanced_pruning_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)

    # Now, train using confidence_fit with a high 15% improvement threshold
    advanced_pruning_model.confidence_fit(train_data, improvement_threshold=0.20)
    advanced_pruning_model.print_asp(simple=True)


    adv_pruning_predictions = advanced_pruning_model.predict(X_test)
    adv_pruning_labels = [p[0] for p in adv_pruning_predictions]
    for i in range(len(adv_pruning_labels)):
        if adv_pruning_labels[i] is None:
            adv_pruning_labels[i] = ('None')

    acc = accuracy_score(Y_test, adv_pruning_labels)

    f1 = f1_score(Y_test, adv_pruning_labels, average=None, labels=["Higher_risk", "Lower_risk"]) #["Higher_risk", "Lower_risk"]["Lower_risk", "Higher_risk"]
    precision = precision_score(Y_test,adv_pruning_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    recall = recall_score(Y_test, adv_pruning_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    
    acc_metrics.append(acc)    
    f1_metrics.append(f1)
    precision_metrics.append(precision)
    recall_metrics.append(recall)

    print("----------------------------------------")
    print()
# Out:
# Fold 0:
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.94723]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=11549.62. [confidence: 0.86842]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>0, range_size(X,N25), N25<=5118144.61. [confidence: 0.67252]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.94. [confidence: 0.81496]
# extinction_risk(X,'lower_risk') :- adult_survival_annual(X,N23), N23<=0.86675, range_size(X,N25), N25>6168290.72. [confidence: 0.80814]
# extinction_risk(X,'higher_risk') :- invasive_species(X,N4), N4>0. [confidence: 0.67708]
# extinction_risk(X,'lower_risk') :- tarsus_length(X,N8), N8<=91.6. [confidence: 0.65951]
# extinction_risk(X,'higher_risk') :- clutch_size(X,N27), N27<=3.73214. [confidence: 0.78333]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N12), N12<=26.25. [confidence: 0.67647]
# extinction_risk(X,'higher_risk') :- order(X,'accipitriformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 1:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94292]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13936.58. [confidence: 0.87544]
# extinction_risk(X,'higher_risk') :- not realm(X,'l'), range_size(X,N25), N25<=5136924.07. [confidence: 0.7214]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=307.1, range_size(X,N25), N25>4233989.28. [confidence: 0.75466]
# extinction_risk(X,'higher_risk') :- not diet(X,'invertebrate'), not habitat(X,'forest'), tail_length(X,N11), N11<=290.4, maximum_latitude(X,N13), N13<=21.45. [confidence: 0.72807]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N17), N17>100, generation_length(X,N24), N24<=3.53453. [confidence: 0.67819]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N7), N7<=33.0, wing_length(X,N9), N9<=337.2. [confidence: 0.67553]
# extinction_risk(X,'higher_risk') :- wing_length(X,N9), N9>237.0. [confidence: 0.85]
# extinction_risk(X,'lower_risk') :- order(X,'piciformes'). [confidence: 0.625]
# extinction_risk(X,'lower_risk') :- order(X,'psittaciformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 2:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94224]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13551.2. [confidence: 0.87694]
# extinction_risk(X,'higher_risk') :- wing_length(X,N9), N9>69.3, range_size(X,N25), N25<=5136924.07. [confidence: 0.68444]
# extinction_risk(X,'lower_risk') :- maximum_elevation(X,N22), N22>1220.0, range_size(X,N25), N25<=19212039.47. [confidence: 0.69431]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>18867090.65. [confidence: 0.8875]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.74138]
# extinction_risk(X,'lower_risk') :- not family(X,'thraupidae'), not realm(X,'ip'), range_size(X,N25), N25>238046.62. [confidence: 0.6875]
# extinction_risk(X,'higher_risk') :- not habitat(X,'forest'). [confidence: 0.8125]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N7), N7>5.0. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8>16.1, tail_length(X,N11), N11<=53.5. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- minimum_elevation(X,N21), N21>160. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- clutch_size(X,N27), N27>2.66129. [confidence: 0.63333]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=22.7. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N7), N7>1.6. [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'caprimulgiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 3:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94125]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13551.2. [confidence: 0.87457]
# extinction_risk(X,'higher_risk') :- not realm(X,'l'), range_size(X,N25), N25<=4754236.34. [confidence: 0.70655]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=304.0, range_size(X,N25), N25>354187.36, range_size(X,N25), N25<=19212039.47. [confidence: 0.67276]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>14023594.92. [confidence: 0.88158]
# extinction_risk(X,'higher_risk') :- generation_length(X,N24), N24>3.53453. [confidence: 0.75543]
# extinction_risk(X,'lower_risk') :- minimum_elevation(X,N21), N21>160. [confidence: 0.67757]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23<=0.70006. [confidence: 0.66923]
# extinction_risk(X,'lower_risk') :- not order(X,'caprimulgiformes'). [confidence: 0.65385]
# extinction_risk(X,'lower_risk') :- order(X,'caprimulgiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 4:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94167]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13551.2. [confidence: 0.88402]
# extinction_risk(X,'higher_risk') :- realm(X,'i'), range_size(X,N25), N25<=5136924.07. [confidence: 0.80493]
# extinction_risk(X,'higher_risk') :- invasive_species(X,N4), N4>0, range_size(X,N25), N25<=5428999.73. [confidence: 0.76053]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>4733640.24. [confidence: 0.73699]
# extinction_risk(X,'higher_risk') :- generation_length(X,N24), N24>3.69385. [confidence: 0.66057]
# extinction_risk(X,'lower_risk') :- not family(X,'thraupidae'), climate_change(X,N5), N5<=0, minimum_latitude(X,N12), N12<=4.25. [confidence: 0.69111]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=57.36. [confidence: 0.67754]
# extinction_risk(X,'lower_risk') :- not order(X,'charadriiformes'). [confidence: 0.625]
# extinction_risk(X,'lower_risk') :- order(X,'charadriiformes'). [confidence: 0.59091]
# ----------------------------------------
#
# Fold 5:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94214]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=11553.33. [confidence: 0.88306]
# extinction_risk(X,'higher_risk') :- not realm(X,'l'), range_size(X,N25), N25<=5136924.07. [confidence: 0.7091]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=298.8, maximum_latitude(X,N13), N13>1.03, range_size(X,N25), N25<=19212039.47. [confidence: 0.66968]
# extinction_risk(X,'higher_risk') :- hand_wing_index(X,N10), N10>18.9, range_size(X,N25), N25<=18867090.65. [confidence: 0.76442]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10>18.3. [confidence: 0.89024]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N7), N7<=4.0. [confidence: 0.7375]
# extinction_risk(X,'higher_risk') :- tail_length(X,N11), N11>203.5. [confidence: 0.7381]
# extinction_risk(X,'lower_risk') :- habitat_breadth(X,N18), N18>2. [confidence: 0.64634]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23<=0.63274. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=23893.22. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- minimum_elevation(X,N21), N21>50. [confidence: 0.69444]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N17), N17>300. [confidence: 0.675]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.625]
# ----------------------------------------
#
# Fold 6:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94096]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13059.51. [confidence: 0.87675]
# extinction_risk(X,'higher_risk') :- realm(X,'i'), range_size(X,N25), N25<=5136924.07. [confidence: 0.80652]
# extinction_risk(X,'higher_risk') :- generation_length(X,N24), N24>3.73041, range_size(X,N25), N25<=5136924.07. [confidence: 0.69777]
# extinction_risk(X,'lower_risk') :- not family(X,'thraupidae'), climate_change(X,N5), N5<=0, maximum_elevation(X,N22), N22>1300.0, range_size(X,N25), N25<=19212039.47. [confidence: 0.71397]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=345124.17. [confidence: 0.66223]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>19212039.47. [confidence: 0.8875]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=18.6. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=2577480.33. [confidence: 0.68269]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>71.39. [confidence: 0.76316]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0, tail_length(X,N11), N11>45.1. [confidence: 0.78]
# extinction_risk(X,'higher_risk') :- not realm(X,'c'), range_size(X,N25), N25>14141336.63. [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- diet_breadth(X,N19), N19>3. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- not realm(X,'c'), order(X,'charadriiformes'). [confidence: 0.67857]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=174.5, maximum_latitude(X,N13), N13>6.82. [confidence: 0.67188]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=19.65. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- invasive_species(X,N4), N4>0. [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N6), N6>29.5. [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'accipitriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 7:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94274]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=11553.33. [confidence: 0.87838]
# extinction_risk(X,'higher_risk') :- realm(X,'i'), wing_length(X,N9), N9<=302.4, range_size(X,N25), N25<=5136924.07. [confidence: 0.76601]
# extinction_risk(X,'higher_risk') :- wing_length(X,N9), N9>302.4, range_size(X,N25), N25<=5136924.07. [confidence: 0.85448]
# extinction_risk(X,'higher_risk') :- wing_length(X,N9), N9>100.0, range_size(X,N25), N25<=2251795.82. [confidence: 0.67868]
# extinction_risk(X,'lower_risk') :- not family(X,'thraupidae'), climate_change(X,N5), N5<=0, maximum_latitude(X,N13), N13>-23.2, range_size(X,N25), N25<=19212039.47. [confidence: 0.66257]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=57.76, range_size(X,N25), N25<=19212039.47. [confidence: 0.69728]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>17578320.62. [confidence: 0.88462]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.75]
# extinction_risk(X,'lower_risk') :- not family(X,'scolopacidae'). [confidence: 0.65]
# extinction_risk(X,'higher_risk') :- habitat_breadth(X,N18), N18<=5. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- order(X,'charadriiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 8:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94183]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=17770.37. [confidence: 0.86842]
# extinction_risk(X,'higher_risk') :- not realm(X,'l'), range_size(X,N25), N25<=5136924.07. [confidence: 0.70218]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>37.47. [confidence: 0.79918]
# extinction_risk(X,'lower_risk') :- habitat(X,'forest'), tail_length(X,N11), N11<=208.8. [confidence: 0.65991]
# extinction_risk(X,'higher_risk') :- realm(X,'l'), tail_length(X,N11), N11<=304.0. [confidence: 0.66239]
# extinction_risk(X,'higher_risk') :- tail_length(X,N11), N11>304.0. [confidence: 0.80357]
# extinction_risk(X,'lower_risk') :- adult_survival_annual(X,N23), N23<=0.84008. [confidence: 0.80435]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N6), N6<=288.1. [confidence: 0.71739]
# extinction_risk(X,'lower_risk') :- order(X,'ciconiiformes'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'pelecaniformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 9:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.9421]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13115.12. [confidence: 0.87675]
# extinction_risk(X,'higher_risk') :- not realm(X,'l'), range_size(X,N25), N25<=5061737.32. [confidence: 0.71139]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=304.0, range_size(X,N25), N25>4233989.28, range_size(X,N25), N25<=19212039.47. [confidence: 0.71786]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>14023594.92. [confidence: 0.87838]
# extinction_risk(X,'higher_risk') :- not diet(X,'invertebrate'), not habitat(X,'forest'), maximum_latitude(X,N13), N13<=21.61. [confidence: 0.7807]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13<=21.61, body_mass(X,N26), N26<=13.8. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13>21.61. [confidence: 0.85]
# extinction_risk(X,'higher_risk') :- clutch_size(X,N27), N27>5.0. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=208.8, maximum_latitude(X,N13), N13>1.27. [confidence: 0.67284]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=11.37, maximum_elevation(X,N22), N22<=2000.0, generation_length(X,N24), N24>2.46906, range_size(X,N25), N25<=163525.7. [confidence: 0.7625]
# extinction_risk(X,'higher_risk') :- generation_length(X,N24), N24<=2.46906. [confidence: 0.76316]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13<=11.37, range_size(X,N25), N25<=928675.91. [confidence: 0.64394]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8<=102.4. [confidence: 0.77586]
# extinction_risk(X,'lower_risk') :- order(X,'galliformes'). [confidence: 0.55]
# extinction_risk(X,'lower_risk') :- order(X,'gruiformes'). [confidence: 0.55]
# ----------------------------------------

# %%
print("Data Driven Model")
print(f"KFold Mean Acc: {round(np.mean(acc_metrics), 5)} | KFold SD: {np.std(acc_metrics)}")
f1_metrics = np.array(f1_metrics)
precision_metrics = np.array(precision_metrics)
recall_metrics = np.array(recall_metrics)

print(f"KFold Mean Precision: Higher Risk {round(np.mean(precision_metrics[:,0]), 5)}, Lower Risk {round(np.mean(precision_metrics[:,1]), 5)}  | KFold SD: {round(np.std(precision_metrics[:, 0]),5), round(np.std(precision_metrics[:, 1]), 5)}")
print(f"KFold Mean Recall: Higher Risk {round(np.mean(recall_metrics[:,0]), 5)}, Lower Risk {round(np.mean(recall_metrics[:,1]), 5)} | KFold SD: {round(np.std(recall_metrics[:, 0]), 5), round(np.std(recall_metrics[:, 1]), 5)}")
print(f"KFold Mean f1: Higher Risk {round(np.mean(f1_metrics[:,0]), 5)}, Lower Risk {round(np.mean(f1_metrics[:,1]), 5)} | KFold SD: {round(np.std(f1_metrics[:,0]), 5), round(np.std(f1_metrics[:,1]), 5)}")
# Out:
# Data Driven Model
# KFold Mean Acc: 0.89771 | KFold SD: 0.007748123584739406
# KFold Mean Precision: Higher Risk 0.76374, Lower Risk 0.92493  | KFold SD: (np.float64(0.03166), np.float64(0.00516))
# KFold Mean Recall: Higher Risk 0.67129, Lower Risk 0.95089 | KFold SD: (np.float64(0.02486), np.float64(0.0083))
# KFold Mean f1: Higher Risk 0.71402, Lower Risk 0.93771 | KFold SD: (np.float64(0.02019), np.float64(0.00484))

# %% [markdown]
# # K-Fold Cross Validation With Human Threats.
# - Expert Rule Model

# %%
acc_metrics = []
f1_metrics = [] 
precision_metrics = []
recall_metrics = []


for i, (train_index, test_index) in enumerate(zip(train_indices, test_indices)):
    print("Fold "+str(i)+":")
    
    train_data = np.concatenate((np.array(X[train_index]), np.array(y[train_index]).reshape(-1, 1)), axis=1).tolist()
    test_data = np.concatenate((np.array(X[test_index]), np.array(y[test_index]).reshape(-1, 1)), axis=1).tolist()
 
    # Prepare the test data (features and true labels)
    X_test = [d[:-1] for d in test_data]
    Y_test = [d[-1] for d in test_data]

    # Instantiate a new classifier for expert-guided model
    expert_model = Classifier(attrs=model_template.attrs.copy(), numeric=model_template.numeric, label=model_template.label)

    # Define our expert rules as strings
    rule1 = "with confidence 0.99 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Agriculture' '==' '1' and 'Invasive_species' '==' '1' and 'Hunting' '==' '1'"
    rule2 = "with confidence 0.95 class = 'Higher_risk' if 'Agriculture' '==' '1' and 'Invasive_species' '==' '1' and 'Hunting' '==' '1'"
    rule3 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Invasive_species' '==' '1' and 'Hunting' '==' '1'"
    rule4 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Agriculture' '==' '1' and 'Hunting' '==' '1'"
    rule5 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Agriculture' '==' '1' and 'Invasive_species' '==' '1'"

    # Add the manual rules to the model
    expert_model.add_manual_rule(rule1, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule2, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule3, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule4, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
    expert_model.add_manual_rule(rule5, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)

    #expert_model.fit(train_data, ratio=0.75)

    expert_model.confidence_fit(train_data, improvement_threshold=0.20)
    expert_model.print_asp(simple=True)


    expert_predictions_tuples = expert_model.predict(X_test)
    expert_predicted_labels = [p[0] for p in expert_predictions_tuples]
    for i in range(len(expert_predicted_labels)):
        if expert_predicted_labels[i] is None:
            expert_predicted_labels[i] = ('None')

    acc = accuracy_score(Y_test, expert_predicted_labels)

    f1 = f1_score(Y_test, expert_predicted_labels, average=None, labels=["Higher_risk", "Lower_risk"]) #["Higher_risk", "Lower_risk"]["Lower_risk", "Higher_risk"]
    precision = precision_score(Y_test,expert_predicted_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    recall = recall_score(Y_test, expert_predicted_labels, average=None, labels=["Higher_risk", "Lower_risk"])
    
    acc_metrics.append(acc)    
    f1_metrics.append(f1)
    precision_metrics.append(precision)
    recall_metrics.append(recall)

    print("----------------------------------------")
    print()
# Out:
# Fold 0:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.9563]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.80636]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.80804]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.68373]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=216.8, minimum_latitude(X,N12), N12<=0.48, range_size(X,N25), N25>5194.76. [confidence: 0.68197]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=8.7. [confidence: 0.79605]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23>0.87526. [confidence: 0.74324]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N17), N17>1600. [confidence: 0.70192]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8<=14.2. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23>0.76115. [confidence: 0.6625]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11>125.2. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- habitat_breadth(X,N18), N18>4. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=49.2. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- wing_length(X,N9), N9<=137.8. [confidence: 0.62]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N6), N6<=25.7. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- not order(X,'psittaciformes'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'psittaciformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 1:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95607]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.81148]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.80455]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.68437]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=19.0, tail_length(X,N11), N11<=243.2, range_size(X,N25), N25>5194.76, range_size(X,N25), N25<=5280448.27. [confidence: 0.71368]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.82432]
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0, clutch_size(X,N27), N27>2.93396. [confidence: 0.79032]
# extinction_risk(X,'higher_risk') :- not realm(X,'c'), wing_length(X,N9), N9>298.0. [confidence: 0.71354]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>2989515.98. [confidence: 0.72321]
# extinction_risk(X,'higher_risk') :- tail_length(X,N11), N11<=100.0. [confidence: 0.65789]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N6), N6>42.1. [confidence: 0.75]
# extinction_risk(X,'lower_risk') :- clutch_size(X,N27), N27<=1.0. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- migration(X,'sedentary'), not habitat(X,'forest'). [confidence: 0.67857]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>548390.11. [confidence: 0.71053]
# extinction_risk(X,'higher_risk') :- clutch_size(X,N27), N27>2.4359. [confidence: 0.71053]
# extinction_risk(X,'lower_risk') :- wing_length(X,N9), N9<=264.2. [confidence: 0.65789]
# extinction_risk(X,'higher_risk') :- not order(X,'accipitriformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'accipitriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 2:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95574]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.79714]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.81532]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.81]
# extinction_risk(X,'lower_risk') :- climate_change(X,N5), N5<=0, tail_length(X,N11), N11<=254.8, range_size(X,N25), N25>1165759.28. [confidence: 0.725]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23>0.86385. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N12), N12>-0.72, maximum_latitude(X,N13), N13>-24.72, minimum_elevation(X,N21), N21<=200. [confidence: 0.69898]
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.6886]
# extinction_risk(X,'higher_risk') :- not family(X,'thamnophilidae'), not family(X,'furnariidae'), minimum_latitude(X,N12), N12>4.83, maximum_elevation(X,N22), N22>500.0, generation_length(X,N24), N24>1.9458. [confidence: 0.75]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>1.4. [confidence: 0.70635]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23>0.79149. [confidence: 0.77586]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25>91223.23, range_size(X,N25), N25<=238046.62. [confidence: 0.77174]
# extinction_risk(X,'lower_risk') :- habitat_breadth(X,N18), N18>2. [confidence: 0.7963]
# extinction_risk(X,'higher_risk') :- minimum_elevation(X,N21), N21<=300. [confidence: 0.66071]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- order(X,'pelecaniformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 3:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95385]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.80294]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.79911]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.69355]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=216.8, range_size(X,N25), N25>585880.91. [confidence: 0.70976]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.78205]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8>66.1. [confidence: 0.69481]
# extinction_risk(X,'lower_risk') :- minimum_elevation(X,N21), N21>200. [confidence: 0.70139]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8<=37.6, elevational_range(X,N17), N17>1580, range_size(X,N25), N25<=479716.63. [confidence: 0.70455]
# extinction_risk(X,'lower_risk') :- tarsus_length(X,N8), N8>30.5. [confidence: 0.67021]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25>454702.62. [confidence: 0.73529]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=425471.32, clutch_size(X,N27), N27>2.0. [confidence: 0.63889]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N12), N12<=7.04. [confidence: 0.67949]
# extinction_risk(X,'higher_risk') :- not order(X,'caprimulgiformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'caprimulgiformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 4:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95555]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.80056]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.81193]
# extinction_risk(X,'lower_risk') :- climate_change(X,N5), N5<=0, hand_wing_index(X,N10), N10<=19.0, tail_length(X,N11), N11<=244.5, range_size(X,N25), N25>5194.76, range_size(X,N25), N25<=5280448.27. [confidence: 0.72689]
# extinction_risk(X,'higher_risk') :- hand_wing_index(X,N10), N10<=19.7, minimum_latitude(X,N12), N12>-55.98, range_size(X,N25), N25<=4733640.24. [confidence: 0.75287]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.6553]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>5614395.75. [confidence: 0.70259]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>0, tarsus_length(X,N8), N8<=53.4, generation_length(X,N24), N24>2.04787, range_size(X,N25), N25<=595328.22, not ab1(X). [confidence: 0.86458]
# extinction_risk(X,'lower_risk') :- tarsus_length(X,N8), N8<=66.9, range_size(X,N25), N25>14083.94. [confidence: 0.66987]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=57.79. [confidence: 0.74167]
# extinction_risk(X,'lower_risk') :- order(X,'accipitriformes'). [confidence: 0.59091]
# ab1(X) :- beak_depth(X,N7), N7<=13.1, maximum_elevation(X,N22), N22<=2450.0, adult_survival_annual(X,N23), N23>0.57328, range_size(X,N25), N25<=251722.97.
# ----------------------------------------
#
# Fold 5:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95546]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.80056]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.81858]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.70192]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=19.0, tail_length(X,N11), N11<=244.5, range_size(X,N25), N25>5194.76, range_size(X,N25), N25<=5280448.27. [confidence: 0.70661]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>5614395.75. [confidence: 0.69068]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.79268]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>0, generation_length(X,N24), N24>6.18817. [confidence: 0.77679]
# extinction_risk(X,'lower_risk') :- wing_length(X,N9), N9>143.4, maximum_latitude(X,N13), N13>-0.58. [confidence: 0.72778]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N7), N7>3.3, tail_length(X,N11), N11<=58.8. [confidence: 0.75]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N7), N7<=4.3. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8>65.6. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N12), N12<=-47.42. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- not realm(X,'a'), elevational_range(X,N17), N17<=850. [confidence: 0.72222]
# extinction_risk(X,'lower_risk') :- minimum_latitude(X,N12), N12<=-4.43. [confidence: 0.67949]
# extinction_risk(X,'higher_risk') :- generation_length(X,N24), N24>2.41219. [confidence: 0.76316]
# extinction_risk(X,'lower_risk') :- not family(X,'emberizidae'). [confidence: 0.65385]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 6:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95525]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.8027]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.80603]
# extinction_risk(X,'lower_risk') :- climate_change(X,N5), N5<=0, tail_length(X,N11), N11<=244.5, range_size(X,N25), N25>5280448.27. [confidence: 0.79703]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.68671]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=13.6, tail_length(X,N11), N11<=216.4, range_size(X,N25), N25>5194.76. [confidence: 0.74615]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.7875]
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0, generation_length(X,N24), N24<=12.68389. [confidence: 0.68077]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8>66.9. [confidence: 0.77344]
# extinction_risk(X,'higher_risk') :- family(X,'thraupidae'). [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- not family(X,'furnariidae'), minimum_latitude(X,N12), N12>-3.83, generation_length(X,N24), N24>2.04787. [confidence: 0.66935]
# extinction_risk(X,'lower_risk') :- minimum_elevation(X,N21), N21>150. [confidence: 0.7625]
# extinction_risk(X,'higher_risk') :- minimum_elevation(X,N21), N21>0. [confidence: 0.67857]
# extinction_risk(X,'lower_risk') :- tarsus_length(X,N8), N8<=49.2, maximum_latitude(X,N13), N13>1.84. [confidence: 0.7069]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25>82843.51, range_size(X,N25), N25<=149530.83. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- habitat_breadth(X,N18), N18<=2, range_size(X,N25), N25>172527.96. [confidence: 0.67241]
# extinction_risk(X,'lower_risk') :- tarsus_length(X,N8), N8<=33.0. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N6), N6>24.3. [confidence: 0.625]
# extinction_risk(X,'lower_risk') :- order(X,'galliformes'). [confidence: 0.55]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 7:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.95151]
# extinction_risk(X,'higher_risk') :- realm(X,'i'), range_size(X,N25), N25<=3453409.14. [confidence: 0.83437]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0, range_size(X,N25), N25<=3453409.14. [confidence: 0.75794]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>53.85. [confidence: 0.79651]
# extinction_risk(X,'lower_risk') :- generation_length(X,N24), N24<=6.18817, range_size(X,N25), N25>2911677.23. [confidence: 0.79091]
# extinction_risk(X,'higher_risk') :- not habitat(X,'forest'), adult_survival_annual(X,N23), N23<=0.58278. [confidence: 0.76531]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>5725.09, body_mass(X,N26), N26<=35.0. [confidence: 0.68478]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8>12.0, clutch_size(X,N27), N27<=2.21795. [confidence: 0.68391]
# extinction_risk(X,'higher_risk') :- tarsus_length(X,N8), N8<=12.0. [confidence: 0.76316]
# extinction_risk(X,'higher_risk') :- beak_length_culmen(X,N6), N6<=75.0, tarsus_length(X,N8), N8>53.0, elevational_range(X,N17), N17<=1300, maximum_elevation(X,N22), N22<=1600.0. [confidence: 0.75926]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>674548.8. [confidence: 0.64035]
# extinction_risk(X,'higher_risk') :- order(X,'psittaciformes'). [confidence: 0.73529]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25>224069.57. [confidence: 0.68519]
# extinction_risk(X,'lower_risk') :- wing_length(X,N9), N9>153.0. [confidence: 0.71154]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N7), N7>3.5, minimum_latitude(X,N12), N12>-4.22. [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N6), N6<=31.6, tail_length(X,N11), N11<=71.9. [confidence: 0.71053]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23<=0.69085. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N6), N6<=19.6. [confidence: 0.65385]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N17), N17<=1055. [confidence: 0.65385]
# extinction_risk(X,'lower_risk') :- not family(X,'thraupidae'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 8:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95487]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.80409]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.80804]
# extinction_risk(X,'lower_risk') :- climate_change(X,N5), N5<=0, tail_length(X,N11), N11<=244.5, range_size(X,N25), N25>766166.49. [confidence: 0.71465]
# extinction_risk(X,'higher_risk') :- generation_length(X,N24), N24>6.7921. [confidence: 0.73667]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.76667]
# extinction_risk(X,'lower_risk') :- minimum_elevation(X,N21), N21>200. [confidence: 0.66176]
# extinction_risk(X,'higher_risk') :- not order(X,'charadriiformes'), not family(X,'picidae'), not realm(X,'a'), not habitat(X,'riparian'), beak_length_culmen(X,N6), N6>11.8, tarsus_length(X,N8), N8>13.1, tail_length(X,N11), N11>38.8, minimum_latitude(X,N12), N12>-28.04, maximum_latitude(X,N13), N13>-19.9, elevational_range(X,N17), N17>100, adult_survival_annual(X,N23), N23<=0.81674, generation_length(X,N24), N24<=5.94328, range_size(X,N25), N25<=339296.54. [confidence: 0.71094]
# extinction_risk(X,'lower_risk') :- not order(X,'charadriiformes'), not diet(X,'granivore'), not diet(X,'fruit'), maximum_latitude(X,N13), N13>-19.9, elevational_range(X,N17), N17>100, diet_breadth(X,N19), N19>2, range_size(X,N25), N25>91345.79. [confidence: 0.75926]
# extinction_risk(X,'higher_risk') :- diet(X,'aquaticanimals'). [confidence: 0.76786]
# extinction_risk(X,'lower_risk') :- not diet(X,'fruit'), minimum_latitude(X,N12), N12<=3.85, maximum_latitude(X,N13), N13>-19.9, maximum_latitude(X,N13), N13<=9.5, adult_survival_annual(X,N23), N23>0.50138. [confidence: 0.63725]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13>-19.9, habitat_breadth(X,N18), N18>4. [confidence: 0.73529]
# extinction_risk(X,'lower_risk') :- tarsus_length(X,N8), N8>19.3. [confidence: 0.65385]
# extinction_risk(X,'higher_risk') :- beak_depth(X,N7), N7>5.1. [confidence: 0.775]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11>32.0. [confidence: 0.58333]
# extinction_risk(X,'higher_risk') :- order(X,'caprimulgiformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------
#
# Fold 9:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95544]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.78902]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.80804]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.69444]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=244.5, range_size(X,N25), N25>5280448.27. [confidence: 0.76733]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=8817.12. [confidence: 0.80233]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=19.0, tail_length(X,N11), N11<=216.4. [confidence: 0.71622]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>0, tarsus_length(X,N8), N8>66.9. [confidence: 0.75962]
# extinction_risk(X,'lower_risk') :- beak_depth(X,N7), N7<=16.0, tail_length(X,N11), N11>82.6. [confidence: 0.69101]
# extinction_risk(X,'higher_risk') :- maximum_latitude(X,N13), N13<=-0.58. [confidence: 0.72807]
# extinction_risk(X,'higher_risk') :- adult_survival_annual(X,N23), N23>0.89958. [confidence: 0.7]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>0, adult_survival_annual(X,N23), N23<=0.8645. [confidence: 0.65833]
# extinction_risk(X,'lower_risk') :- elevational_range(X,N17), N17>1700. [confidence: 0.78571]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25<=2806304.39. [confidence: 0.64286]
# extinction_risk(X,'higher_risk') :- order(X,'accipitriformes'). [confidence: 0.59091]
# extinction_risk(X,'higher_risk') :- order(X,'coraciiformes'). [confidence: 0.55]
# extinction_risk(X,'higher_risk') :- order(X,'passeriformes'). [confidence: 0.55]
# ----------------------------------------

# %%
print("Expert Rule Model")
print(f"KFold Mean Acc: {round(np.mean(acc_metrics), 5)} | KFold SD: {np.std(acc_metrics)}")
f1_metrics = np.array(f1_metrics)
precision_metrics = np.array(precision_metrics)
recall_metrics = np.array(recall_metrics)

print(f"KFold Mean Precision: Higher Risk {round(np.mean(precision_metrics[:,0]), 5)}, Lower Risk {round(np.mean(precision_metrics[:,1]), 5)}  | KFold SD: {round(np.std(precision_metrics[:, 0]),5), round(np.std(precision_metrics[:, 1]), 5)}")
print(f"KFold Mean Recall: Higher Risk {round(np.mean(recall_metrics[:,0]), 5)}, Lower Risk {round(np.mean(recall_metrics[:,1]), 5)} | KFold SD: {round(np.std(recall_metrics[:, 0]), 5), round(np.std(recall_metrics[:, 1]), 5)}")
print(f"KFold Mean f1: Higher Risk {round(np.mean(f1_metrics[:,0]), 5)}, Lower Risk {round(np.mean(f1_metrics[:,1]), 5)} | KFold SD: {round(np.std(f1_metrics[:,0]), 5), round(np.std(f1_metrics[:,1]), 5)}")
# Out:
# Expert Rule Model
# KFold Mean Acc: 0.90324 | KFold SD: 0.008232344762685827
# KFold Mean Precision: Higher Risk 0.7547, Lower Risk 0.93708  | KFold SD: (np.float64(0.02922), np.float64(0.00605))
# KFold Mean Recall: Higher Risk 0.73001, Lower Risk 0.94394 | KFold SD: (np.float64(0.02739), np.float64(0.009))
# KFold Mean f1: Higher Risk 0.74164, Lower Risk 0.94046 | KFold SD: (np.float64(0.02047), np.float64(0.0052))

# %% [markdown]
# # Training on Complete Dataset
# - withought Expert Rules
# - and with Human Threats

# %%
baseline_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)
train_data = np.concatenate((np.array(X), np.array(y).reshape(-1, 1)), axis=1).tolist()

advanced_pruning_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)
advanced_pruning_model.confidence_fit(train_data, improvement_threshold=0.20)
advanced_pruning_model.print_asp(simple=True)
# Out:
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0. [confidence: 0.94195]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=13551.2. [confidence: 0.87655]
# extinction_risk(X,'higher_risk') :- not realm(X,'l'), range_size(X,N25), N25<=5136924.07. [confidence: 0.70704]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=304.0, maximum_latitude(X,N13), N13>1.03, range_size(X,N25), N25<=19212039.47, body_mass(X,N26), N26<=79.2. [confidence: 0.77899]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>19212039.47. [confidence: 0.89024]
# extinction_risk(X,'higher_risk') :- tail_length(X,N11), N11>304.0. [confidence: 0.82258]
# extinction_risk(X,'lower_risk') :- not realm(X,'p'), maximum_elevation(X,N22), N22>1600.0, adult_survival_annual(X,N23), N23<=0.87484, range_size(X,N25), N25>354187.36. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- not realm(X,'p'), beak_depth(X,N7), N7>3.3, hand_wing_index(X,N10), N10>18.9. [confidence: 0.68155]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>74565.61. [confidence: 0.66814]
# extinction_risk(X,'higher_risk') :- minimum_elevation(X,N21), N21<=900. [confidence: 0.69512]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>17643.08. [confidence: 0.68519]
# extinction_risk(X,'higher_risk') :- not order(X,'galliformes'). [confidence: 0.625]
# extinction_risk(X,'higher_risk') :- order(X,'galliformes'). [confidence: 0.55]

# %% [markdown]
# # Training on Complete Dataset
# - With Expert Rules
# - and with Human Threats

# %%
train_data = np.concatenate((np.array(X), np.array(y).reshape(-1, 1)), axis=1).tolist()

expert_model = Classifier(attrs=model_template.attrs, numeric=model_template.numeric, label=model_template.label)

# Define our expert rules as strings
rule1 = "with confidence 0.99 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Agriculture' '==' '1' and 'Invasive_species' '==' '1' and 'Hunting' '==' '1'"
rule2 = "with confidence 0.95 class = 'Higher_risk' if 'Agriculture' '==' '1' and 'Invasive_species' '==' '1' and 'Hunting' '==' '1'"
rule3 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Invasive_species' '==' '1' and 'Hunting' '==' '1'"
rule4 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Agriculture' '==' '1' and 'Hunting' '==' '1'"
rule5 = "with confidence 0.95 class = 'Higher_risk' if 'Range_size' '<=' '75321' and 'Agriculture' '==' '1' and 'Invasive_species' '==' '1'"

# Add the manual rules to the model
expert_model.add_manual_rule(rule1, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule2, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule3, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule4, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)
expert_model.add_manual_rule(rule5, model_template.attrs, model_template.numeric, ['Lower_risk', 'Higher_risk'], instructions=False)

#expert_model.fit(train_data, ratio=0.75)

expert_model.confidence_fit(train_data, improvement_threshold=0.20)
expert_model.print_asp(simple=True)
# Out:
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.99]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, invasive_species(X,N4), N4>1. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- hunting(X,N3), N3>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, hunting(X,N3), N3>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>1, invasive_species(X,N4), N4>1, range_size(X,N25), N25<=75321. [confidence: 0.95]
# extinction_risk(X,'lower_risk') :- hunting(X,N3), N3<=0. [confidence: 0.95533]
# extinction_risk(X,'higher_risk') :- realm(X,'i'). [confidence: 0.80256]
# extinction_risk(X,'lower_risk') :- maximum_latitude(X,N13), N13>65.53. [confidence: 0.80894]
# extinction_risk(X,'higher_risk') :- climate_change(X,N5), N5>0. [confidence: 0.68644]
# extinction_risk(X,'lower_risk') :- hand_wing_index(X,N10), N10<=19.0, tail_length(X,N11), N11<=244.5, range_size(X,N25), N25>5194.76, range_size(X,N25), N25<=5280448.27. [confidence: 0.71591]
# extinction_risk(X,'lower_risk') :- range_size(X,N25), N25>5614395.75. [confidence: 0.69685]
# extinction_risk(X,'higher_risk') :- range_size(X,N25), N25<=5194.76. [confidence: 0.80682]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2>0, tarsus_length(X,N8), N8>66.9. [confidence: 0.78889]
# extinction_risk(X,'lower_risk') :- agriculture(X,N2), N2<=0, generation_length(X,N24), N24<=12.93458. [confidence: 0.6681]
# extinction_risk(X,'higher_risk') :- tail_length(X,N11), N11<=58.8, generation_length(X,N24), N24>1.9458. [confidence: 0.75]
# extinction_risk(X,'higher_risk') :- agriculture(X,N2), N2<=0, tail_length(X,N11), N11>61.0. [confidence: 0.7]
# extinction_risk(X,'lower_risk') :- tail_length(X,N11), N11<=61.0. [confidence: 0.71875]
# extinction_risk(X,'higher_risk') :- elevational_range(X,N17), N17>1275, maximum_elevation(X,N22), N22<=2200.0. [confidence: 0.75806]
# extinction_risk(X,'lower_risk') :- maximum_elevation(X,N22), N22>1600.0. [confidence: 0.76087]
# extinction_risk(X,'higher_risk') :- diet(X,'omnivore'), range_size(X,N25), N25<=2074732.63. [confidence: 0.71875]
# extinction_risk(X,'lower_risk') :- habitat_breadth(X,N18), N18>2, minimum_elevation(X,N21), N21<=450. [confidence: 0.73214]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N12), N12>-5.71. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- minimum_latitude(X,N12), N12<=-15.03. [confidence: 0.65789]
# extinction_risk(X,'lower_risk') :- beak_length_culmen(X,N6), N6>20.4. [confidence: 0.67857]
# extinction_risk(X,'higher_risk') :- not family(X,'sturnidae'). [confidence: 0.59091]
# extinction_risk(X,'lower_risk') :- order(X,'passeriformes'). [confidence: 0.55]
